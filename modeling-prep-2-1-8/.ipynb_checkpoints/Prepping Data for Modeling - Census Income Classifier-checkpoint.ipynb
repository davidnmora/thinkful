# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %% [markdown]
# # Data Prep for Modeling
#
# ## Dataset
#
# 32,000 people's info, with a binary classification of over or under 50k income/year, rom USI ML website.["Predict whether income exceeds $50K/yr based on census data. Also known as "Census Income" dataset".](https://archive.ics.uci.edu/ml/datasets/Adult)
#
# Listing of attributes:
#
# __Outcome variable__: <=50K.
#
# __Columns:__
# - __age__: continuous.
# - workclass: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.
# - fnlwgt: continuous.
# - education: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.
# - __education-num__: continuous.
# - marital-status: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.
# __occupation__: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, - Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.
# - relationship: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.
# - __race__: White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black.
# - __sex__: Female, Male.
# - capital-gain: continuous.
# - capital-loss: continuous.
# - __hours-per-week__: continuous.
# - native-country: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands.

# %%
sns.set_style("white")
df = pd.read_csv('adult.data')
df.columns = ['age',
'workclass',
'fnlwgt',
'education',
'education-num',
'marital-status',
'occupation',
'relationship',
'race',
'sex',
'capital-gain',
'capital-loss',
'hours-per-week',
'native-country',
'income<=50K'
             ]

# %% [markdown]
# ### Make classifier col boolean

# %%
df['income<=50K'] = (df['income<=50K'].str.strip() == '<=50K')
df
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 0       50   Self-emp-not-inc   83311      Bachelors             13
# 1       38            Private  215646        HS-grad              9
# 2       53            Private  234721           11th              7
# 3       28            Private  338409      Bachelors             13
# 4       37            Private  284582        Masters             14
# 5       49            Private  160187            9th              5
# 6       52   Self-emp-not-inc  209642        HS-grad              9
# 7       31            Private   45781        Masters             14
# 8       42            Private  159449      Bachelors             13
# 9       37            Private  280464   Some-college             10
# 10      30          State-gov  141297      Bachelors             13
# 11      23            Private  122272      Bachelors             13
# 12      32            Private  205019     Assoc-acdm             12
# 13      40            Private  121772      Assoc-voc             11
# 14      34            Private  245487        7th-8th              4
# 15      25   Self-emp-not-inc  176756        HS-grad              9
# 16      32            Private  186824        HS-grad              9
# 17      38            Private   28887           11th              7
# 18      43   Self-emp-not-inc  292175        Masters             14
# 19      40            Private  193524      Doctorate             16
# 20      54            Private  302146        HS-grad              9
# 21      35        Federal-gov   76845            9th              5
# 22      43            Private  117037           11th              7
# 23      59            Private  109015        HS-grad              9
# 24      56          Local-gov  216851      Bachelors             13
# 25      19            Private  168294        HS-grad              9
# 26      54                  ?  180211   Some-college             10
# 27      39            Private  367260        HS-grad              9
# 28      49            Private  193366        HS-grad              9
# 29      23          Local-gov  190709     Assoc-acdm             12
# ...    ...                ...     ...            ...            ...
# 32530   30                  ?   33811      Bachelors             13
# 32531   34            Private  204461      Doctorate             16
# 32532   54            Private  337992      Bachelors             13
# 32533   37            Private  179137   Some-college             10
# 32534   22            Private  325033           12th              8
# 32535   34            Private  160216      Bachelors             13
# 32536   30            Private  345898        HS-grad              9
# 32537   38            Private  139180      Bachelors             13
# 32538   71                  ?  287372      Doctorate             16
# 32539   45          State-gov  252208        HS-grad              9
# 32540   41                  ?  202822        HS-grad              9
# 32541   72                  ?  129912        HS-grad              9
# 32542   45          Local-gov  119199     Assoc-acdm             12
# 32543   31            Private  199655        Masters             14
# 32544   39          Local-gov  111499     Assoc-acdm             12
# 32545   37            Private  198216     Assoc-acdm             12
# 32546   43            Private  260761        HS-grad              9
# 32547   65   Self-emp-not-inc   99359    Prof-school             15
# 32548   43          State-gov  255835   Some-college             10
# 32549   43   Self-emp-not-inc   27242   Some-college             10
# 32550   32            Private   34066           10th              6
# 32551   43            Private   84661      Assoc-voc             11
# 32552   32            Private  116138        Masters             14
# 32553   53            Private  321865        Masters             14
# 32554   22            Private  310152   Some-college             10
# 32555   27            Private  257302     Assoc-acdm             12
# 32556   40            Private  154374        HS-grad              9
# 32557   58            Private  151910        HS-grad              9
# 32558   22            Private  201490        HS-grad              9
# 32559   52       Self-emp-inc  287927        HS-grad              9
#
#                marital-status          occupation     relationship  \
# 0          Married-civ-spouse     Exec-managerial          Husband
# 1                    Divorced   Handlers-cleaners    Not-in-family
# 2          Married-civ-spouse   Handlers-cleaners          Husband
# 3          Married-civ-spouse      Prof-specialty             Wife
# 4          Married-civ-spouse     Exec-managerial             Wife
# 5       Married-spouse-absent       Other-service    Not-in-family
# 6          Married-civ-spouse     Exec-managerial          Husband
# 7               Never-married      Prof-specialty    Not-in-family
# 8          Married-civ-spouse     Exec-managerial          Husband
# 9          Married-civ-spouse     Exec-managerial          Husband
# 10         Married-civ-spouse      Prof-specialty          Husband
# 11              Never-married        Adm-clerical        Own-child
# 12              Never-married               Sales    Not-in-family
# 13         Married-civ-spouse        Craft-repair          Husband
# 14         Married-civ-spouse    Transport-moving          Husband
# 15              Never-married     Farming-fishing        Own-child
# 16              Never-married   Machine-op-inspct        Unmarried
# 17         Married-civ-spouse               Sales          Husband
# 18                   Divorced     Exec-managerial        Unmarried
# 19         Married-civ-spouse      Prof-specialty          Husband
# 20                  Separated       Other-service        Unmarried
# 21         Married-civ-spouse     Farming-fishing          Husband
# 22         Married-civ-spouse    Transport-moving          Husband
# 23                   Divorced        Tech-support        Unmarried
# 24         Married-civ-spouse        Tech-support          Husband
# 25              Never-married        Craft-repair        Own-child
# 26         Married-civ-spouse                   ?          Husband
# 27                   Divorced     Exec-managerial    Not-in-family
# 28         Married-civ-spouse        Craft-repair          Husband
# 29              Never-married     Protective-serv    Not-in-family
# ...                       ...                 ...              ...
# 32530           Never-married                   ?    Not-in-family
# 32531      Married-civ-spouse      Prof-specialty          Husband
# 32532      Married-civ-spouse     Exec-managerial          Husband
# 32533                Divorced        Adm-clerical        Unmarried
# 32534           Never-married     Protective-serv        Own-child
# 32535           Never-married     Exec-managerial    Not-in-family
# 32536           Never-married        Craft-repair    Not-in-family
# 32537                Divorced      Prof-specialty        Unmarried
# 32538      Married-civ-spouse                   ?          Husband
# 32539               Separated        Adm-clerical        Own-child
# 32540               Separated                   ?    Not-in-family
# 32541      Married-civ-spouse                   ?          Husband
# 32542                Divorced      Prof-specialty        Unmarried
# 32543                Divorced       Other-service    Not-in-family
# 32544      Married-civ-spouse        Adm-clerical             Wife
# 32545                Divorced        Tech-support    Not-in-family
# 32546      Married-civ-spouse   Machine-op-inspct          Husband
# 32547           Never-married      Prof-specialty    Not-in-family
# 32548                Divorced        Adm-clerical   Other-relative
# 32549      Married-civ-spouse        Craft-repair          Husband
# 32550      Married-civ-spouse   Handlers-cleaners          Husband
# 32551      Married-civ-spouse               Sales          Husband
# 32552           Never-married        Tech-support    Not-in-family
# 32553      Married-civ-spouse     Exec-managerial          Husband
# 32554           Never-married     Protective-serv    Not-in-family
# 32555      Married-civ-spouse        Tech-support             Wife
# 32556      Married-civ-spouse   Machine-op-inspct          Husband
# 32557                 Widowed        Adm-clerical        Unmarried
# 32558           Never-married        Adm-clerical        Own-child
# 32559      Married-civ-spouse     Exec-managerial             Wife
#
#                       race      sex  capital-gain  capital-loss  \
# 0                    White     Male             0             0
# 1                    White     Male             0             0
# 2                    Black     Male             0             0
# 3                    Black   Female             0             0
# 4                    White   Female             0             0
# 5                    Black   Female             0             0
# 6                    White     Male             0             0
# 7                    White   Female         14084             0
# 8                    White     Male          5178             0
# 9                    Black     Male             0             0
# 10      Asian-Pac-Islander     Male             0             0
# 11                   White   Female             0             0
# 12                   Black     Male             0             0
# 13      Asian-Pac-Islander     Male             0             0
# 14      Amer-Indian-Eskimo     Male             0             0
# 15                   White     Male             0             0
# 16                   White     Male             0             0
# 17                   White     Male             0             0
# 18                   White   Female             0             0
# 19                   White     Male             0             0
# 20                   Black   Female             0             0
# 21                   Black     Male             0             0
# 22                   White     Male             0          2042
# 23                   White   Female             0             0
# 24                   White     Male             0             0
# 25                   White     Male             0             0
# 26      Asian-Pac-Islander     Male             0             0
# 27                   White     Male             0             0
# 28                   White     Male             0             0
# 29                   White     Male             0             0
# ...                    ...      ...           ...           ...
# 32530   Asian-Pac-Islander   Female             0             0
# 32531                White     Male             0             0
# 32532   Asian-Pac-Islander     Male             0             0
# 32533                White   Female             0             0
# 32534                Black     Male             0             0
# 32535                White   Female             0             0
# 32536                Black     Male             0             0
# 32537                Black   Female         15020             0
# 32538                White     Male             0             0
# 32539                White   Female             0             0
# 32540                Black   Female             0             0
# 32541                White     Male             0             0
# 32542                White   Female             0             0
# 32543                Other   Female             0             0
# 32544                White   Female             0             0
# 32545                White   Female             0             0
# 32546                White     Male             0             0
# 32547                White     Male          1086             0
# 32548                White   Female             0             0
# 32549                White     Male             0             0
# 32550   Amer-Indian-Eskimo     Male             0             0
# 32551                White     Male             0             0
# 32552   Asian-Pac-Islander     Male             0             0
# 32553                White     Male             0             0
# 32554                White     Male             0             0
# 32555                White   Female             0             0
# 32556                White     Male             0             0
# 32557                White   Female             0             0
# 32558                White     Male             0             0
# 32559                White   Female         15024             0
#
#        hours-per-week  native-country  income<=50K
# 0                  13   United-States         True
# 1                  40   United-States         True
# 2                  40   United-States         True
# 3                  40            Cuba         True
# 4                  40   United-States         True
# 5                  16         Jamaica         True
# 6                  45   United-States        False
# 7                  50   United-States        False
# 8                  40   United-States        False
# 9                  80   United-States        False
# 10                 40           India        False
# 11                 30   United-States         True
# 12                 50   United-States         True
# 13                 40               ?        False
# 14                 45          Mexico         True
# 15                 35   United-States         True
# 16                 40   United-States         True
# 17                 50   United-States         True
# 18                 45   United-States        False
# 19                 60   United-States        False
# 20                 20   United-States         True
# 21                 40   United-States         True
# 22                 40   United-States         True
# 23                 40   United-States         True
# 24                 40   United-States        False
# 25                 40   United-States         True
# 26                 60           South        False
# 27                 80   United-States         True
# 28                 40   United-States         True
# 29                 52   United-States         True
# ...               ...             ...          ...
# 32530              99   United-States         True
# 32531              60   United-States        False
# 32532              50           Japan        False
# 32533              39   United-States         True
# 32534              35   United-States         True
# 32535              55   United-States        False
# 32536              46   United-States         True
# 32537              45   United-States        False
# 32538              10   United-States        False
# 32539              40   United-States         True
# 32540              32   United-States         True
# 32541              25   United-States         True
# 32542              48   United-States         True
# 32543              30   United-States         True
# 32544              20   United-States        False
# 32545              40   United-States         True
# 32546              40          Mexico         True
# 32547              60   United-States         True
# 32548              40   United-States         True
# 32549              50   United-States         True
# 32550              40   United-States         True
# 32551              45   United-States         True
# 32552              11          Taiwan         True
# 32553              40   United-States        False
# 32554              40   United-States         True
# 32555              38   United-States         True
# 32556              40   United-States        False
# 32557              40   United-States         True
# 32558              20   United-States         True
# 32559              40   United-States        False
#
# [32560 rows x 15 columns]

# %% [markdown]
# ### Strip whitespace

# %%
df = df.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

# %%
df['capital-change'] = df['capital-gain'] - df['capital-loss']
df
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 0       50  Self-emp-not-inc   83311     Bachelors             13
# 1       38           Private  215646       HS-grad              9
# 2       53           Private  234721          11th              7
# 3       28           Private  338409     Bachelors             13
# 4       37           Private  284582       Masters             14
# 5       49           Private  160187           9th              5
# 6       52  Self-emp-not-inc  209642       HS-grad              9
# 7       31           Private   45781       Masters             14
# 8       42           Private  159449     Bachelors             13
# 9       37           Private  280464  Some-college             10
# 10      30         State-gov  141297     Bachelors             13
# 11      23           Private  122272     Bachelors             13
# 12      32           Private  205019    Assoc-acdm             12
# 13      40           Private  121772     Assoc-voc             11
# 14      34           Private  245487       7th-8th              4
# 15      25  Self-emp-not-inc  176756       HS-grad              9
# 16      32           Private  186824       HS-grad              9
# 17      38           Private   28887          11th              7
# 18      43  Self-emp-not-inc  292175       Masters             14
# 19      40           Private  193524     Doctorate             16
# 20      54           Private  302146       HS-grad              9
# 21      35       Federal-gov   76845           9th              5
# 22      43           Private  117037          11th              7
# 23      59           Private  109015       HS-grad              9
# 24      56         Local-gov  216851     Bachelors             13
# 25      19           Private  168294       HS-grad              9
# 26      54                 ?  180211  Some-college             10
# 27      39           Private  367260       HS-grad              9
# 28      49           Private  193366       HS-grad              9
# 29      23         Local-gov  190709    Assoc-acdm             12
# ...    ...               ...     ...           ...            ...
# 32530   30                 ?   33811     Bachelors             13
# 32531   34           Private  204461     Doctorate             16
# 32532   54           Private  337992     Bachelors             13
# 32533   37           Private  179137  Some-college             10
# 32534   22           Private  325033          12th              8
# 32535   34           Private  160216     Bachelors             13
# 32536   30           Private  345898       HS-grad              9
# 32537   38           Private  139180     Bachelors             13
# 32538   71                 ?  287372     Doctorate             16
# 32539   45         State-gov  252208       HS-grad              9
# 32540   41                 ?  202822       HS-grad              9
# 32541   72                 ?  129912       HS-grad              9
# 32542   45         Local-gov  119199    Assoc-acdm             12
# 32543   31           Private  199655       Masters             14
# 32544   39         Local-gov  111499    Assoc-acdm             12
# 32545   37           Private  198216    Assoc-acdm             12
# 32546   43           Private  260761       HS-grad              9
# 32547   65  Self-emp-not-inc   99359   Prof-school             15
# 32548   43         State-gov  255835  Some-college             10
# 32549   43  Self-emp-not-inc   27242  Some-college             10
# 32550   32           Private   34066          10th              6
# 32551   43           Private   84661     Assoc-voc             11
# 32552   32           Private  116138       Masters             14
# 32553   53           Private  321865       Masters             14
# 32554   22           Private  310152  Some-college             10
# 32555   27           Private  257302    Assoc-acdm             12
# 32556   40           Private  154374       HS-grad              9
# 32557   58           Private  151910       HS-grad              9
# 32558   22           Private  201490       HS-grad              9
# 32559   52      Self-emp-inc  287927       HS-grad              9
#
#               marital-status         occupation    relationship  \
# 0         Married-civ-spouse    Exec-managerial         Husband
# 1                   Divorced  Handlers-cleaners   Not-in-family
# 2         Married-civ-spouse  Handlers-cleaners         Husband
# 3         Married-civ-spouse     Prof-specialty            Wife
# 4         Married-civ-spouse    Exec-managerial            Wife
# 5      Married-spouse-absent      Other-service   Not-in-family
# 6         Married-civ-spouse    Exec-managerial         Husband
# 7              Never-married     Prof-specialty   Not-in-family
# 8         Married-civ-spouse    Exec-managerial         Husband
# 9         Married-civ-spouse    Exec-managerial         Husband
# 10        Married-civ-spouse     Prof-specialty         Husband
# 11             Never-married       Adm-clerical       Own-child
# 12             Never-married              Sales   Not-in-family
# 13        Married-civ-spouse       Craft-repair         Husband
# 14        Married-civ-spouse   Transport-moving         Husband
# 15             Never-married    Farming-fishing       Own-child
# 16             Never-married  Machine-op-inspct       Unmarried
# 17        Married-civ-spouse              Sales         Husband
# 18                  Divorced    Exec-managerial       Unmarried
# 19        Married-civ-spouse     Prof-specialty         Husband
# 20                 Separated      Other-service       Unmarried
# 21        Married-civ-spouse    Farming-fishing         Husband
# 22        Married-civ-spouse   Transport-moving         Husband
# 23                  Divorced       Tech-support       Unmarried
# 24        Married-civ-spouse       Tech-support         Husband
# 25             Never-married       Craft-repair       Own-child
# 26        Married-civ-spouse                  ?         Husband
# 27                  Divorced    Exec-managerial   Not-in-family
# 28        Married-civ-spouse       Craft-repair         Husband
# 29             Never-married    Protective-serv   Not-in-family
# ...                      ...                ...             ...
# 32530          Never-married                  ?   Not-in-family
# 32531     Married-civ-spouse     Prof-specialty         Husband
# 32532     Married-civ-spouse    Exec-managerial         Husband
# 32533               Divorced       Adm-clerical       Unmarried
# 32534          Never-married    Protective-serv       Own-child
# 32535          Never-married    Exec-managerial   Not-in-family
# 32536          Never-married       Craft-repair   Not-in-family
# 32537               Divorced     Prof-specialty       Unmarried
# 32538     Married-civ-spouse                  ?         Husband
# 32539              Separated       Adm-clerical       Own-child
# 32540              Separated                  ?   Not-in-family
# 32541     Married-civ-spouse                  ?         Husband
# 32542               Divorced     Prof-specialty       Unmarried
# 32543               Divorced      Other-service   Not-in-family
# 32544     Married-civ-spouse       Adm-clerical            Wife
# 32545               Divorced       Tech-support   Not-in-family
# 32546     Married-civ-spouse  Machine-op-inspct         Husband
# 32547          Never-married     Prof-specialty   Not-in-family
# 32548               Divorced       Adm-clerical  Other-relative
# 32549     Married-civ-spouse       Craft-repair         Husband
# 32550     Married-civ-spouse  Handlers-cleaners         Husband
# 32551     Married-civ-spouse              Sales         Husband
# 32552          Never-married       Tech-support   Not-in-family
# 32553     Married-civ-spouse    Exec-managerial         Husband
# 32554          Never-married    Protective-serv   Not-in-family
# 32555     Married-civ-spouse       Tech-support            Wife
# 32556     Married-civ-spouse  Machine-op-inspct         Husband
# 32557                Widowed       Adm-clerical       Unmarried
# 32558          Never-married       Adm-clerical       Own-child
# 32559     Married-civ-spouse    Exec-managerial            Wife
#
#                      race     sex  capital-gain  capital-loss  hours-per-week  \
# 0                   White    Male             0             0              13
# 1                   White    Male             0             0              40
# 2                   Black    Male             0             0              40
# 3                   Black  Female             0             0              40
# 4                   White  Female             0             0              40
# 5                   Black  Female             0             0              16
# 6                   White    Male             0             0              45
# 7                   White  Female         14084             0              50
# 8                   White    Male          5178             0              40
# 9                   Black    Male             0             0              80
# 10     Asian-Pac-Islander    Male             0             0              40
# 11                  White  Female             0             0              30
# 12                  Black    Male             0             0              50
# 13     Asian-Pac-Islander    Male             0             0              40
# 14     Amer-Indian-Eskimo    Male             0             0              45
# 15                  White    Male             0             0              35
# 16                  White    Male             0             0              40
# 17                  White    Male             0             0              50
# 18                  White  Female             0             0              45
# 19                  White    Male             0             0              60
# 20                  Black  Female             0             0              20
# 21                  Black    Male             0             0              40
# 22                  White    Male             0          2042              40
# 23                  White  Female             0             0              40
# 24                  White    Male             0             0              40
# 25                  White    Male             0             0              40
# 26     Asian-Pac-Islander    Male             0             0              60
# 27                  White    Male             0             0              80
# 28                  White    Male             0             0              40
# 29                  White    Male             0             0              52
# ...                   ...     ...           ...           ...             ...
# 32530  Asian-Pac-Islander  Female             0             0              99
# 32531               White    Male             0             0              60
# 32532  Asian-Pac-Islander    Male             0             0              50
# 32533               White  Female             0             0              39
# 32534               Black    Male             0             0              35
# 32535               White  Female             0             0              55
# 32536               Black    Male             0             0              46
# 32537               Black  Female         15020             0              45
# 32538               White    Male             0             0              10
# 32539               White  Female             0             0              40
# 32540               Black  Female             0             0              32
# 32541               White    Male             0             0              25
# 32542               White  Female             0             0              48
# 32543               Other  Female             0             0              30
# 32544               White  Female             0             0              20
# 32545               White  Female             0             0              40
# 32546               White    Male             0             0              40
# 32547               White    Male          1086             0              60
# 32548               White  Female             0             0              40
# 32549               White    Male             0             0              50
# 32550  Amer-Indian-Eskimo    Male             0             0              40
# 32551               White    Male             0             0              45
# 32552  Asian-Pac-Islander    Male             0             0              11
# 32553               White    Male             0             0              40
# 32554               White    Male             0             0              40
# 32555               White  Female             0             0              38
# 32556               White    Male             0             0              40
# 32557               White  Female             0             0              40
# 32558               White    Male             0             0              20
# 32559               White  Female         15024             0              40
#
#       native-country  income<=50K  capital-change
# 0      United-States         True               0
# 1      United-States         True               0
# 2      United-States         True               0
# 3               Cuba         True               0
# 4      United-States         True               0
# 5            Jamaica         True               0
# 6      United-States        False               0
# 7      United-States        False           14084
# 8      United-States        False            5178
# 9      United-States        False               0
# 10             India        False               0
# 11     United-States         True               0
# 12     United-States         True               0
# 13                 ?        False               0
# 14            Mexico         True               0
# 15     United-States         True               0
# 16     United-States         True               0
# 17     United-States         True               0
# 18     United-States        False               0
# 19     United-States        False               0
# 20     United-States         True               0
# 21     United-States         True               0
# 22     United-States         True           -2042
# 23     United-States         True               0
# 24     United-States        False               0
# 25     United-States         True               0
# 26             South        False               0
# 27     United-States         True               0
# 28     United-States         True               0
# 29     United-States         True               0
# ...              ...          ...             ...
# 32530  United-States         True               0
# 32531  United-States        False               0
# 32532          Japan        False               0
# 32533  United-States         True               0
# 32534  United-States         True               0
# 32535  United-States        False               0
# 32536  United-States         True               0
# 32537  United-States        False           15020
# 32538  United-States        False               0
# 32539  United-States         True               0
# 32540  United-States         True               0
# 32541  United-States         True               0
# 32542  United-States         True               0
# 32543  United-States         True               0
# 32544  United-States        False               0
# 32545  United-States         True               0
# 32546         Mexico         True               0
# 32547  United-States         True            1086
# 32548  United-States         True               0
# 32549  United-States         True               0
# 32550  United-States         True               0
# 32551  United-States         True               0
# 32552         Taiwan         True               0
# 32553  United-States        False               0
# 32554  United-States         True               0
# 32555  United-States         True               0
# 32556  United-States        False               0
# 32557  United-States         True               0
# 32558  United-States         True               0
# 32559  United-States        False           15024
#
# [32560 rows x 16 columns]

# %% [markdown]
# # Explore the variables using the univariate and bivariate methods you've learned so far. *Note: I've moved explorations specific to certain features to where that feature is created.*

# %%
# Make the scatterplot matrix
# Set the default plot aesthetics to be prettier.
sns.set_style("white")

# Because the variables can only take integer values between 0 and 10, points
# on the scatterplot will hide one another. To better see all the points, we
# create a dataframe of random noise (or "jitter") and add it only when plotting.

# Make a copy of the data to add jitter to and plot.
df_jittered = df.loc[:, ['education-num', 'age', 'capital-change', 'hours-per-week']].dropna()
# Making the random noise.
jitter = pd.DataFrame(
    np.random.uniform(-.3, .3, size=(df_jittered.shape)),
    columns=df_jittered.columns
)
# Combine the data and the noise.
df_jittered = df_jittered.add(jitter)

# Declare that you want to make a scatterplot matrix.
g = sns.PairGrid(df_jittered.dropna(), diag_sharey=False)
# Scatterplot.
g.map_upper(plt.scatter, alpha=.01)
# Fit line summarizing the linear relationship of the two variables.
g.map_lower(sns.regplot, scatter_kws=dict(alpha=0))
# Give information about the univariate distributions of the variables.
g.map_diag(sns.kdeplot, lw=3)
plt.show()

# %%
# Make the correlation matrix.
corrmat = df.corr()
print(corrmat)

# Set up the matplotlib figure.
f, ax = plt.subplots(figsize=(12, 9))

# Draw the heatmap using seaborn.
sns.heatmap(corrmat, vmax=.8, square=True)
plt.show()
# Out:
#                      age    fnlwgt  education-num  capital-gain  capital-loss  \
# age             1.000000 -0.076646       0.036527      0.077674      0.057775
# fnlwgt         -0.076646  1.000000      -0.043159      0.000437     -0.010259
# education-num   0.036527 -0.043159       1.000000      0.122627      0.079932
# capital-gain    0.077674  0.000437       0.122627      1.000000     -0.031614
# capital-loss    0.057775 -0.010259       0.079932     -0.031614      1.000000
# hours-per-week  0.068756 -0.018770       0.148127      0.078409      0.054256
# income<=50K    -0.234039  0.009481      -0.335182     -0.223333     -0.150523
# capital-change  0.074284  0.000993       0.117888      0.998521     -0.085901
#
#                 hours-per-week  income<=50K  capital-change
# age                   0.068756    -0.234039        0.074284
# fnlwgt               -0.018770     0.009481        0.000993
# education-num         0.148127    -0.335182        0.117888
# capital-gain          0.078409    -0.223333        0.998521
# capital-loss          0.054256    -0.150523       -0.085901
# hours-per-week        1.000000    -0.229690        0.075207
# income<=50K          -0.229690     1.000000       -0.214432
# capital-change        0.075207    -0.214432        1.000000

# %%
sns.scatterplot(x="hours-per-week", y='education-num', data=df)

# %%
df['hours-per-week'].hist(bins=40)

# %%
df['education-num'].hist()

# %%
df['income<=50K'].sum() / len(df['income<=50K'])
# Out:
# 0.7591830466830467

# %%
# Plot counts for each combination of levels.
sns.countplot(y="sex", hue="race", data=df, palette="Greens_d")
plt.show()

# # Table of counts
counttable = pd.crosstab(df['sex'], df['race'])
print(counttable)

# Test will return a chi-square test statistic and a p-value. Like the t-test,
# the chi-square is compared against a distribution (the chi-square
# distribution) to determine whether the group size differences are large
# enough to reflect differences in the population.
print(stats.chisquare(counttable, axis=None))
# Out:
# race    Amer-Indian-Eskimo  Asian-Pac-Islander  Black  Other  White
# sex
# Female                 119                 346   1555    109   8642
# Male                   192                 693   1569    162  19173
# Power_divergenceResult(statistic=104988.21683046684, pvalue=0.0)

# %% [markdown]
# ### Most people are originally from the US in the dastaset

# %%
# # Table of counts
counttable = pd.crosstab(df['sex'], df['native-country'])
print(counttable)

# Test will return a chi-square test statistic and a p-value. Like the t-test,
# the chi-square is compared against a distribution (the chi-square
# distribution) to determine whether the group size differences are large
# enough to reflect differences in the population.
print(stats.chisquare(counttable, axis=None))
# Out:
# native-country    ?  Cambodia  Canada  China  Columbia  Cuba  \
# sex
# Female          163         3      39     21        24    40
# Male            420        16      82     54        35    55
#
# native-country  Dominican-Republic  Ecuador  El-Salvador  England     ...      \
# sex                                                                   ...
# Female                          35        9           35       32     ...
# Male                            35       19           71       58     ...
#
# native-country  Portugal  Puerto-Rico  Scotland  South  Taiwan  Thailand  \
# sex
# Female                12           52         5     30      15        11
# Male                  25           62         7     50      36         7
#
# native-country  Trinadad&Tobago  United-States  Vietnam  Yugoslavia
# sex
# Female                       11           9682       23           3
# Male                          8          19487       44          13
#
# [2 rows x 42 columns]
# Power_divergenceResult(statistic=1190444.0265356267, pvalue=0.0)

# %%
non_us = df[df['native-country'] != 'United-States']['income<=50K']
non_us.sum() / len(non_us)
# Out:
# 0.8024181657328222

# %%
len(df)
# Out:
# 32560

# %% [markdown]
# # *Generating Features*
#
# ## Based on what you learned via your data exploration, *create 10 new features*. Explain the reasoning behind each one.
#
# ## Use filtering methods to select the five best features. justify your choices.

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   50  Self-emp-not-inc   83311  Bachelors             13
# 1   38           Private  215646    HS-grad              9
# 2   53           Private  234721       11th              7
# 3   28           Private  338409  Bachelors             13
# 4   37           Private  284582    Masters             14
#
#        marital-status         occupation   relationship   race     sex  \
# 0  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 1            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 2  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 3  Married-civ-spouse     Prof-specialty           Wife  Black  Female
# 4  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#    capital-gain  capital-loss  hours-per-week native-country  income<=50K  \
# 0             0             0              13  United-States         True
# 1             0             0              40  United-States         True
# 2             0             0              40  United-States         True
# 3             0             0              40           Cuba         True
# 4             0             0              40  United-States         True
#
#    capital-change
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0

# %%
model_df = df[['income<=50K', 'sex']]
model_df
# Out:
#        income<=50K     sex
# 0             True    Male
# 1             True    Male
# 2             True    Male
# 3             True  Female
# 4             True  Female
# 5             True  Female
# 6            False    Male
# 7            False  Female
# 8            False    Male
# 9            False    Male
# 10           False    Male
# 11            True  Female
# 12            True    Male
# 13           False    Male
# 14            True    Male
# 15            True    Male
# 16            True    Male
# 17            True    Male
# 18           False  Female
# 19           False    Male
# 20            True  Female
# 21            True    Male
# 22            True    Male
# 23            True  Female
# 24           False    Male
# 25            True    Male
# 26           False    Male
# 27            True    Male
# 28            True    Male
# 29            True    Male
# ...            ...     ...
# 32530         True  Female
# 32531        False    Male
# 32532        False    Male
# 32533         True  Female
# 32534         True    Male
# 32535        False  Female
# 32536         True    Male
# 32537        False  Female
# 32538        False    Male
# 32539         True  Female
# 32540         True  Female
# 32541         True    Male
# 32542         True  Female
# 32543         True  Female
# 32544        False  Female
# 32545         True  Female
# 32546         True    Male
# 32547         True    Male
# 32548         True  Female
# 32549         True    Male
# 32550         True    Male
# 32551         True    Male
# 32552         True    Male
# 32553        False    Male
# 32554         True    Male
# 32555         True  Female
# 32556        False    Male
# 32557         True  Female
# 32558         True    Male
# 32559        False  Female
#
# [32560 rows x 2 columns]

# %% [markdown]
# ### 1. `is_working_age`, ie 18 to 65?
# __Questions__: This one I feel very unsure on, partly because it's had to see in the skewed distribution, but also because I think maybe I should ask "are you in key high earning stage of life?" ie 35<age<55?

# %%
model_df.loc[:,'is_working_age'] = df.loc[:,'age'].apply(lambda age: (20 < age < 60))
# Out:
#                 income<=50K     sex is_working_age capital_gain>=5K full_time  \
# 0                       1.0    Male           True            False     False
# 1                       1.0    Male           True            False      True
# 2                       1.0    Male           True            False      True
# 3                       1.0  Female           True            False      True
# 4                       1.0  Female           True            False      True
# 5                       1.0  Female           True            False     False
# 6                       0.0    Male           True            False      True
# 7                       0.0  Female           True             True      True
# 8                       0.0    Male           True             True      True
# 9                       0.0    Male           True            False      True
# 10                      0.0    Male           True            False      True
# 11                      1.0  Female           True            False     False
# 12                      1.0    Male           True            False      True
# 13                      0.0    Male           True            False      True
# 14                      1.0    Male           True            False      True
# 15                      1.0    Male           True            False      True
# 16                      1.0    Male           True            False      True
# 17                      1.0    Male           True            False      True
# 18                      0.0  Female           True            False      True
# 19                      0.0    Male           True            False      True
# 20                      1.0  Female           True            False     False
# 21                      1.0    Male           True            False      True
# 22                      1.0    Male           True            False      True
# 23                      1.0  Female           True            False      True
# 24                      0.0    Male           True            False      True
# 25                      1.0    Male          False            False      True
# 26                      0.0    Male           True            False      True
# 27                      1.0    Male           True            False      True
# 28                      1.0    Male           True            False      True
# 29                      1.0    Male           True            False      True
# ...                     ...     ...            ...              ...       ...
# 32531                   0.0    Male           True            False      True
# 32532                   0.0    Male           True            False      True
# 32533                   1.0  Female           True            False      True
# 32534                   1.0    Male           True            False      True
# 32535                   0.0  Female           True            False      True
# 32536                   1.0    Male           True            False      True
# 32537                   0.0  Female           True             True      True
# 32538                   0.0    Male          False            False     False
# 32539                   1.0  Female           True            False      True
# 32540                   1.0  Female           True            False     False
# 32541                   1.0    Male          False            False     False
# 32542                   1.0  Female           True            False      True
# 32543                   1.0  Female           True            False     False
# 32544                   0.0  Female           True            False     False
# 32545                   1.0  Female           True            False      True
# 32546                   1.0    Male           True            False      True
# 32547                   1.0    Male          False            False      True
# 32548                   1.0  Female           True            False      True
# 32549                   1.0    Male           True            False      True
# 32550                   1.0    Male           True            False      True
# 32551                   1.0    Male           True            False      True
# 32552                   1.0    Male           True            False     False
# 32553                   0.0    Male           True            False      True
# 32554                   1.0    Male           True            False      True
# 32555                   1.0  Female           True            False      True
# 32556                   0.0    Male           True            False      True
# 32557                   1.0  Female           True            False      True
# 32558                   1.0    Male           True            False     False
# 32559                   0.0  Female           True             True      True
# is_working_age          NaN     NaN            NaN              NaN       NaN
#
#                college_or_greater has_never_married
# 0                            True             False
# 1                           False             False
# 2                           False             False
# 3                            True             False
# 4                            True             False
# 5                           False             False
# 6                           False             False
# 7                            True              True
# 8                            True             False
# 9                           False             False
# 10                           True             False
# 11                           True              True
# 12                          False              True
# 13                          False             False
# 14                          False             False
# 15                          False              True
# 16                          False              True
# 17                          False             False
# 18                           True             False
# 19                           True             False
# 20                          False             False
# 21                          False             False
# 22                          False             False
# 23                          False             False
# 24                           True             False
# 25                          False              True
# 26                          False             False
# 27                          False             False
# 28                          False             False
# 29                          False              True
# ...                           ...               ...
# 32531                        True             False
# 32532                        True             False
# 32533                       False             False
# 32534                       False              True
# 32535                        True              True
# 32536                       False              True
# 32537                        True             False
# 32538                        True             False
# 32539                       False             False
# 32540                       False             False
# 32541                       False             False
# 32542                       False             False
# 32543                        True             False
# 32544                       False             False
# 32545                       False             False
# 32546                       False             False
# 32547                        True              True
# 32548                       False             False
# 32549                       False             False
# 32550                       False             False
# 32551                       False             False
# 32552                        True              True
# 32553                        True             False
# 32554                       False              True
# 32555                       False             False
# 32556                       False             False
# 32557                       False             False
# 32558                       False              True
# 32559                       False             False
# is_working_age                NaN               NaN
#
# [32561 rows x 7 columns]

# %%
df['age'].hist()

# %%
# Plot all the variables with boxplots for each country.
g = sns.FacetGrid(df, col="income<=50K", size=4, aspect=1)
g = g.map(sns.violinplot, "age")
plt.show()

# # Test whether group differences are significant.
# for col in model_df.loc[:,'tvtot':'sclmeet'].columns:
#     print(col)
for col in ['age']:
    print(col)
    print(stats.ttest_ind(
        df[df['income<=50K'] == True][col].dropna(),
        df[df['income<=50K'] == False][col].dropna()
    ))
# Out:
# age
# Ttest_indResult(statistic=-43.43590585792797, pvalue=0.0)

# %% [markdown]
# ### 2. `capital_gain>=5K`, capital gain >= 5K
# People with high capital gains tend to be higher income.
#
# __Question:__ is 14K/16K predicted correctly significant enough to worry about in a data of 32K people? Or is that *precisely* why it's important to focus on the *specificity* of a dataset which overrepresents __positive cases (<=50K)__?

# %%
df[df['capital-change'] > 5000]['income<=50K'].describe()
# Out:
# count      1648
# unique        2
# top       False
# freq       1496
# Name: income<=50K, dtype: object

# %%
model_df.loc[:,'capital_gain>=5K'] = df.loc[:,'capital-change'].apply(lambda cc: cc >= 5000)

# %% [markdown]
# ### 3. `full_time`, ie between horus >= 35
# I notice that the there's a huge part of the population that works full time, both male and female, and then those who don't. Those who work much more than 35 hours tend to have make >50K.
#
# __Questions:__ should I break it up into *3* categorical variables: <35, 35<hrs<45, 45<hrs?

# %%
model_df.loc[:,'full_time'] = df.loc[:,'hours-per-week'].apply(lambda hours: hours >= 35)

# %%
# Plot all the variables with boxplots for each country.
g = sns.FacetGrid(df, col="sex", size=4, aspect=1)
g = g.map(sns.violinplot, "hours-per-week")
plt.show()

# # Test whether group differences are significant.
for col in ['hours-per-week']:
    print(col)
    print(stats.ttest_ind(
        df[df['sex'] == 'Male'][col].dropna(),
        df[df['sex'] == 'Female'][col].dropna()
    ))
# Out:
# hours-per-week
# Ttest_indResult(statistic=42.50936339903957, pvalue=0.0)

# %%
# Plot all the variables with boxplots for each country.
g = sns.FacetGrid(df, col="income<=50K", size=4, aspect=1)
g = g.map(sns.violinplot, "hours-per-week")
plt.show()

# # Test whether group differences are significant.
for col in ['hours-per-week']:
    print(col)
    print(stats.ttest_ind(
        df[df['income<=50K'] == True][col].dropna(),
        df[df['income<=50K'] == False][col].dropna()
    ))
# Out:
# hours-per-week
# Ttest_indResult(statistic=-42.58331943927707, pvalue=0.0)

# %% [markdown]
# ### 4. `college_or_greater`, ie educatoin_num >= 13
# People with college degrees or greater have higher wages.

# %%
model_df.loc[:,'college_or_greater'] = df.loc[:,'education-num'].apply(lambda ed: ed >= 13)

# %%
df[df['education-num'] >= 13]['income<=50K'].describe()
# Out:
# count     8066
# unique       2
# top       True
# freq      4157
# Name: income<=50K, dtype: object

# %%
# Plot all the variables with boxplots for each country.
g = sns.FacetGrid(df, col="income<=50K", size=4, aspect=1)
g = g.map(sns.violinplot, "education-num")
plt.show()

# %%
# Plot counts for each combination of levels.
sns.countplot(y="college_or_greater", hue="income<=50K", data=model_df, palette="Greens_d")
plt.show()

# # Table of counts
counttable = pd.crosstab(model_df['college_or_greater'], model_df['income<=50K'])
print(counttable)

# Test will return a chi-square test statistic and a p-value. Like the t-test,
# the chi-square is compared against a distribution (the chi-square
# distribution) to determine whether the group size differences are large
# enough to reflect differences in the population.
print(stats.chisquare(counttable, axis=None))
# Out:
# income<=50K          0.0    1.0
# college_or_greater
# False               3932  20562
# True                3909   4157
# Power_divergenceResult(statistic=25279.975184275183, pvalue=0.0)

# %% [markdown]
# ### 5. `has_never_married`, `never-maried` == True ...
# __Question__: would it be more effective to just say "are you under 30?"

# %%
model_df.loc[:,'has_never_married'] = df.loc[:,'marital-status'].apply(lambda status: status == 'Never-married')

# %%
df[df['marital-status'] == 'Never-married']['age'].hist()

# %%
# Plot counts for each combination of levels.
sns.countplot(y="marital-status", hue="income<=50K", data=df, palette="Greens_d")
plt.show()

# # Table of counts
counttable = pd.crosstab(df['marital-status'], df['income<=50K'])
print(counttable)
print(stats.chisquare(counttable, axis=None))
# Out:
# income<=50K            False  True
# marital-status
# Divorced                 463   3980
# Married-AF-spouse         10     13
# Married-civ-spouse      6692   8284
# Married-spouse-absent     34    384
# Never-married            491  10191
# Separated                 66    959
# Widowed                   85    908
# Power_divergenceResult(statistic=68683.93157248157, pvalue=0.0)

# %%
# Plot counts for each combination of levels.
sns.countplot(y="marital-status", hue="race", data=df, palette="Greens_d")
plt.show()

# # Table of counts
counttable = pd.crosstab(df['marital-status'], df['race'])
print(counttable)
print(stats.chisquare(counttable, axis=None))
# Out:
# race                   Amer-Indian-Eskimo  Asian-Pac-Islander  Black  Other  \
# marital-status
# Divorced                               60                  75    485     26
# Married-AF-spouse                       0                   0      1      0
# Married-civ-spouse                    116                 508    837    105
# Married-spouse-absent                   9                  41     62     15
# Never-married                         103                 372   1346    105
# Separated                              11                  19    265     13
# Widowed                                12                  24    128      7
#
# race                   White
# marital-status
# Divorced                3797
# Married-AF-spouse         22
# Married-civ-spouse     13410
# Married-spouse-absent    291
# Never-married           8756
# Separated                717
# Widowed                  822
# Power_divergenceResult(statistic=263565.81787469285, pvalue=0.0)
